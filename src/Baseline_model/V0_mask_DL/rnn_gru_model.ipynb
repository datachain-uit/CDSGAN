# %%
import pandas as pd
import numpy as np
import os
import time
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (
    classification_report, accuracy_score, balanced_accuracy_score,
    f1_score, precision_score, recall_score,
    matthews_corrcoef, cohen_kappa_score, confusion_matrix
)

import seaborn as sns
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
class HybridDataset(Dataset):
    def __init__(self, X_seq, X_static, y, seq_lengths):
        self.X_seq = torch.FloatTensor(X_seq)
        self.X_static = torch.FloatTensor(X_static)
        self.y = torch.LongTensor(y)
        self.seq_lengths = torch.LongTensor(seq_lengths)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return (
            self.X_seq[idx],
            self.X_static[idx],
            self.seq_lengths[idx],
            self.y[idx]
        )

# %%
class HybridMaskedRecurrentModel(nn.Module):
    def __init__(self, seq_input_dim, static_dim, hidden_dim, num_classes, rnn_type="lstm"):
        super().__init__()
        self.rnn_type = rnn_type
        bidirectional = rnn_type == "bilstm"

        if rnn_type == "rnn":
            self.recurrent = nn.RNN(seq_input_dim, hidden_dim, batch_first=True)
        elif rnn_type == "lstm":
            self.recurrent = nn.LSTM(seq_input_dim, hidden_dim, batch_first=True)
        elif rnn_type == "gru":
            self.recurrent = nn.GRU(seq_input_dim, hidden_dim, batch_first=True)
        elif rnn_type == "bilstm":
            self.recurrent = nn.LSTM(
                seq_input_dim,
                hidden_dim,
                batch_first=True,
                bidirectional=True
            )

        out_dim = hidden_dim * 2 if bidirectional else hidden_dim
        self.fc = nn.Linear(out_dim + static_dim, num_classes)

    def forward(self, x_seq, x_static, seq_lengths):
        # pack sequence (IMPORTANT)
        packed = pack_padded_sequence(
            x_seq,
            seq_lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )
    
        packed_out, hidden = self.recurrent(packed)
    
        if self.rnn_type == "bilstm":
            h_n, _ = hidden
            out = torch.cat([h_n[-2], h_n[-1]], dim=1)
        elif self.rnn_type == "lstm":
            h_n, _ = hidden
            out = h_n[-1]
        else:
            out = hidden[-1]
    
        out = torch.cat([out, x_static], dim=1)
        return self.fc(out)

# %%
# Metrics
def gmean_score(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    per_class = []
    for i in range(cm.shape[0]):
        tp = cm[i,i]
        fn = cm[i].sum() - tp
        fp = cm[:,i].sum() - tp
        tn = cm.sum() - tp - fn - fp
        sens = tp / (tp + fn) if (tp + fn) > 0 else 0
        spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        per_class.append(np.sqrt(sens * spec))
    return np.prod(per_class) ** (1/len(per_class)) if per_class else 0

def gmean_per_class(y_true, y_pred, target_class):
    cm = confusion_matrix(y_true, y_pred)
    i = target_class
    tp = cm[i,i]
    fn = cm[i].sum() - tp
    fp = cm[:,i].sum() - tp
    tn = cm.sum() - tp - fn - fp

    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    return np.sqrt(recall * specificity)

def print_results(
    version_name,
    phase,
    y_true,
    y_pred,
    time_build_model=None,
    time_predict=None
):
    target_names = ['Excellent', 'Good', 'Average']

    print(f"\n{'='*30} {version_name} - Phase {phase} {'='*30}")
    print(classification_report(
        y_true,
        y_pred,
        digits=10,
        target_names=target_names
    ))

    # Precision / Recall / F1 theo từng class
    prec_per_class = precision_score(y_true, y_pred, average=None)
    rec_per_class  = recall_score(y_true, y_pred, average=None)
    f1_per_class   = f1_score(y_true, y_pred, average=None)

    # G-Mean per class
    gmean_classes = [
        gmean_per_class(y_true, y_pred, i)
        for i in range(len(target_names))
    ]

    print("G-Mean per class (one-vs-rest):")
    for idx, name in enumerate(target_names):
        print(f"  {name:<10}: {gmean_classes[idx]:.10f}")
        
    print()

    # ===== TẠO DICTIONARY METRICS =====
    metrics = {
        'Version': version_name,
        'Phase': phase,

        'TimeBuildModel': time_build_model,
        'TimePredict': time_predict,

        'Accuracy': accuracy_score(y_true, y_pred),
        'BalancedAcc': balanced_accuracy_score(y_true, y_pred),

        'Precision Macro': precision_score(y_true, y_pred, average='macro'),
        'Precision Weighted': precision_score(y_true, y_pred, average='weighted'),

        'Recall Macro': recall_score(y_true, y_pred, average='macro'),
        'Recall Weighted': recall_score(y_true, y_pred, average='weighted'),

        'F1-Score Macro': f1_score(y_true, y_pred, average='macro'),
        'F1-Score Weighted': f1_score(y_true, y_pred, average='weighted'),

        'GMean': gmean_score(y_true, y_pred),

        'MCC': matthews_corrcoef(y_true, y_pred),
        'Kappa': cohen_kappa_score(y_true, y_pred),
    }

    # ===== THÊM METRIC CHO TỪNG CLASS =====
    for i, name in enumerate(target_names):
        metrics[f'Precision_{name}'] = prec_per_class[i]
        metrics[f'Recall_{name}'] = rec_per_class[i]
        metrics[f'F1-Score_{name}'] = f1_per_class[i]
        metrics[f'G-Mean_{name}'] = gmean_classes[i]

    # In ra console
    for k, v in metrics.items():
        if k not in ['Version', 'Phase'] and v is not None:
            print(f"{k:22} : {v:.10f}")

    return metrics

# %%
def evaluate_hybrid_model(
    model,
    loader,
    device,
    dataset_name,
    output_dir="results"
):
    os.makedirs(output_dir, exist_ok=True)

    model.eval()

    all_preds = []
    all_probs = []
    all_labels = []

    with torch.no_grad():
        for xb_seq, xb_static, xb_len, yb in loader:
            xb_seq = xb_seq.to(device)
            xb_static = xb_static.to(device)
            xb_len = xb_len.to(device)

            outputs = model(xb_seq, xb_static, xb_len)
            probs = torch.softmax(outputs, dim=1)

            # FIX 1: preds lấy từ probs (KHÔNG từ outputs)
            preds = torch.argmax(probs, dim=1)

            # FIX 2: dùng append thay vì extend
            all_probs.append(probs.cpu().numpy())
            all_preds.append(preds.cpu().numpy())
            all_labels.append(yb.numpy())

    # FIX 3: concat thay vì np.array
    y_true = np.concatenate(all_labels, axis=0)
    y_pred = np.concatenate(all_preds, axis=0)
    y_prob = np.concatenate(all_probs, axis=0)

    # ===== Confusion Matrix =====
    cm = confusion_matrix(y_true, y_pred)

    cm_path = f"{output_dir}/confusion_matrix_{dataset_name}.csv"
    pd.DataFrame(cm).to_csv(cm_path, index=False)

    # Plot CM
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix - {dataset_name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")


    # ===== Probability matrix =====
    prob_path = f"{output_dir}/probability_matrix_{dataset_name}.csv"

    df_prob = pd.DataFrame(
        y_prob,
        columns=[f"Prob_Class_{i}" for i in range(y_prob.shape[1])]
    )
    df_prob["y_true"] = y_true
    df_prob["y_pred"] = y_pred

    df_prob.to_csv(prob_path, index=False)

    print(f"Saved confusion matrix to: {cm_path}")
    print(f"Saved probability matrix to: {prob_path}")

    return y_true, y_pred

# %%
def prepare_and_train_hybrid(train_path, val_path=None, rnn_type="lstm"):
    print(f"Loading train: {train_path}")
    df_train = pd.read_parquet(train_path)

    if val_path:
        df_val = pd.read_parquet(val_path)
        print(f"Train: {len(df_train)} | Val: {len(df_val)}")
    else:
        df_val = None
        print(f"Only train: {len(df_train)} samples")

    # ===== CHỈ dùng train để fit =====
    df = df_train.copy()

    df = df.drop(columns=['user_id', 'course_id'], errors='ignore')

    # ===== Tách label =====
    y = df['label_3'].values
    df_features = df.drop('label_3', axis=1)

    # ===== Lấy feature time-series =====
    phase_cols = [
        col for col in df_features.columns
        if any(f"_p{p}_" in col for p in ['1', '2', '3', '4'])
    ]

    phases_data = []
    for p in ['1', '2', '3', '4']:
        cols_p = [c for c in phase_cols if f"_p{p}_" in c]
        print(f"Phase {p}: {len(cols_p)} features")
        phases_data.append(df_features[cols_p].values)

    X_seq = np.stack(phases_data, axis=1)

    # ===== Timestep mask =====
    seq_lengths = (np.abs(X_seq).sum(axis=2) > 0).sum(axis=1)
    seq_lengths = np.maximum(seq_lengths, 1)

    print(f"Time-series shape: {X_seq.shape}")

    # ===== Static features =====
    static_cols = [c for c in df_features.columns if c not in phase_cols]
    X_static = df_features[static_cols].values

    print(f"Static feature shape: {X_static.shape}")

    # ===== Normalize (FIT TRÊN TRAIN) =====
    scaler_seq = StandardScaler()
    N, T, F = X_seq.shape
    X_seq = scaler_seq.fit_transform(X_seq.reshape(-1, F)).reshape(N, T, F)
    X_seq = np.nan_to_num(X_seq, nan=0.0, posinf=0.0, neginf=0.0)

    scaler_static = StandardScaler()
    X_static = scaler_static.fit_transform(X_static)
    X_static = np.nan_to_num(X_static, nan=0.0, posinf=0.0, neginf=0.0)

    # ===== Encode label =====
    le = LabelEncoder()
    y_enc = le.fit_transform(y)

    print(f"Classes: {le.classes_}")

    # ===== TRAIN DATASET =====
    train_dataset = HybridDataset(
        X_seq,
        X_static,
        y_enc,
        seq_lengths
    )
    train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)

    # ===== VALIDATION DATASET =====
    if df_val is not None:
        df_val = df_val.drop(columns=['user_id', 'course_id'], errors='ignore')

        y_val = df_val['label_3'].values
        df_val_features = df_val.drop('label_3', axis=1)

        # ===== sequence =====
        phases_val = []
        for p in ['1', '2', '3', '4']:
            cols_p = [c for c in phase_cols if f"_p{p}_" in c]
            phases_val.append(df_val_features[cols_p].values)

        X_seq_val = np.stack(phases_val, axis=1)

        seq_len_val = (np.abs(X_seq_val).sum(axis=2) > 0).sum(axis=1)
        seq_len_val = np.maximum(seq_len_val, 1)

        # ===== static =====
        X_static_val = df_val_features[static_cols].values

        # ===== scale (dùng scaler train) =====
        N_val, T, F = X_seq_val.shape
        X_seq_val = scaler_seq.transform(X_seq_val.reshape(-1, F)).reshape(N_val, T, F)
        X_seq_val = np.nan_to_num(X_seq_val, nan=0.0, posinf=0.0, neginf=0.0)

        X_static_val = scaler_static.transform(X_static_val)
        X_static_val = np.nan_to_num(X_static_val, nan=0.0, posinf=0.0, neginf=0.0)

        y_val_enc = le.transform(y_val)

        val_dataset = HybridDataset(
            X_seq_val,
            X_static_val,
            y_val_enc,
            seq_len_val
        )

        val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)
    else:
        val_loader = None

    # ===== MODEL =====
    model = HybridMaskedRecurrentModel(
        seq_input_dim=F,
        static_dim=X_static.shape[1],
        hidden_dim=128,
        num_classes=len(le.classes_),
        rnn_type=rnn_type
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    # ===== TRAINING =====
    best_val_loss = float('inf')
    best_state = None
    patience = 10
    wait = 0

    for epoch in range(50):

        # ===== TRAIN =====
        model.train()
        train_loss = 0

        for xb_seq, xb_static, xb_len, yb in train_loader:
            xb_seq = xb_seq.to(device)
            xb_static = xb_static.to(device)
            xb_len = xb_len.to(device)
            yb = yb.to(device)

            optimizer.zero_grad()
            out = model(xb_seq, xb_static, xb_len)
            loss = criterion(out, yb)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)

        # ===== VALIDATION =====
        if val_loader is not None:
            model.eval()
            val_loss = 0

            with torch.no_grad():
                for xb_seq, xb_static, xb_len, yb in val_loader:
                    xb_seq = xb_seq.to(device)
                    xb_static = xb_static.to(device)
                    xb_len = xb_len.to(device)
                    yb = yb.to(device)

                    out = model(xb_seq, xb_static, xb_len)
                    loss = criterion(out, yb)

                    val_loss += loss.item()

            val_loss /= len(val_loader)

            print(f"Epoch {epoch+1}: train_loss = {train_loss:.4f} | val_loss = {val_loss:.4f}")

            # ===== EARLY STOPPING =====
            if val_loss < best_val_loss - 1e-4:
                best_val_loss = val_loss
                best_state = model.state_dict()
                wait = 0
            else:
                wait += 1
                if wait >= patience:
                    print(f"Early stopping at epoch {epoch+1}")
                    break
        else:
            print(f"Epoch {epoch+1}: train_loss = {train_loss:.4f}")

    # ===== LOAD BEST =====
    if best_state is not None:
        model.load_state_dict(best_state)

    model.eval()
    print("Training done")

    return model, scaler_seq, scaler_static, le, phase_cols, static_cols

# %%
def run_and_report_hybrid(
    model,
    loader,
    device,
    dataset_name,
    version_name="HybridModel",
    phase="All"
):
    y_true, y_pred = evaluate_hybrid_model(
        model, loader, device, dataset_name
    )

    metrics = print_results(
        version_name=version_name,
        phase=phase,
        y_true=y_true,
        y_pred=y_pred
    )

    metrics_path = f"results/metrics_{dataset_name}.csv"
    pd.DataFrame([metrics]).to_csv(metrics_path, index=False)

    print(f"Saved metrics to: {metrics_path}")

    return metrics

# %%
base_path = "/kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw"

# %%
import time

def run_experiment_hybrid(
    base_path,
    train_file,
    val_file,
    test_prefix,
    version_name,
    rnn_type="lstm"
):
    print(f"\n{'#'*5}")
    print(f"Version: {version_name}")
    print(f"{'#'*5}")

    train_path = f"{base_path}/{train_file}"
    val_path   = f"{base_path}/{val_file}"

    test_files = [
        f"{base_path}/{test_prefix}_1.parquet",
        f"{base_path}/{test_prefix}_2.parquet",
        f"{base_path}/{test_prefix}_3.parquet",
        f"{base_path}/{test_prefix}_4.parquet",
    ]

    # ===== Train =====
    start_train = time.perf_counter()

    model, scaler_seq, scaler_static, le, phase_cols, static_cols = \
        prepare_and_train_hybrid(
            train_path,
            val_path,
            rnn_type=rnn_type
        )

    time_build_model = time.perf_counter() - start_train
    results = []

    model.eval()
    with torch.no_grad():
        for phase, test_path in enumerate(test_files, 1):
            print(f"\n--- Test Phase {phase}: {test_path} ---")

            df_test = pd.read_parquet(test_path)
            df_test = df_test.drop(columns=['user_id', 'course_id'], errors='ignore')

            # ===== Label =====
            y_test = df_test['label_3'].values
            y_test_enc = le.transform(y_test)

            df_features = df_test.drop('label_3', axis=1)

            # ===== Time-series =====
            phases_data = []
            for p in ['1', '2', '3', '4']:
                cols_p = [c for c in phase_cols if f"_p{p}_" in c]
                phases_data.append(df_features[cols_p].values)

            X_seq = np.stack(phases_data, axis=1)   # (N, T, F)

            # ===== Static =====
            X_static = df_features[static_cols].values

            phase_exist = (~np.isnan(X_seq)).any(axis=2)   # (N, T)

            seq_lengths = phase_exist.sum(axis=1)

            # KHÔNG drop sample
            seq_lengths = np.maximum(seq_lengths, 1)

            # Thay NaN bằng 0 để đưa vào model
            X_seq = np.nan_to_num(X_seq, nan=0.0)
            X_static = np.nan_to_num(X_static, nan=0.0)

            # ===== Scaling =====
            N, T, F = X_seq.shape
            X_seq_scaled = scaler_seq.transform(
                X_seq.reshape(-1, F)
            ).reshape(N, T, F)

            X_static_scaled = scaler_static.transform(X_static)

            # ===== Tensor =====
            X_seq_tensor = torch.FloatTensor(X_seq_scaled).to(device)
            X_static_tensor = torch.FloatTensor(X_static_scaled).to(device)
            seq_lengths_tensor = torch.LongTensor(seq_lengths).to(device)

            # ===== Predict =====
            start_pred = time.perf_counter()

            outputs = model(
                X_seq_tensor,
                X_static_tensor,
                seq_lengths_tensor
            )

            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            time_predict = time.perf_counter() - start_pred

            # ===== Metrics =====
            res = print_results(
                version_name=version_name,
                phase=phase,
                y_true=y_test_enc,
                y_pred=preds,
                time_build_model=time_build_model,
                time_predict=time_predict
            )

            # ===== Confusion + Probability =====
            run_and_report_hybrid(
                model=model,
                loader=DataLoader(
                    HybridDataset(
                        X_seq_scaled,
                        X_static_scaled,
                        y_test_enc,
                        seq_lengths
                    ),
                    batch_size=256,
                    shuffle=False
                ),
                device=device,
                dataset_name=f"{version_name}_phase{phase}"
            )

            results.append(res)

    # ===== Summary dataframe =====
    df = pd.DataFrame(results).round(10)

    # Đổi tên cột cho đúng
    df = df.rename(columns={
        "PrecMacro": "Precision Macro",
        "PrecWeighted": "Precision Weighted",
        "RecMacro": "Recall Macro",
        "RecWeighted": "Recall Weighted",
        "F1Macro": "F1-Score Macro",
        "F1Weighted": "F1-Score Weighted",
    })

    ordered_cols = [
        "Version",
        "Phase",
        "TimeBuildModel",
        "TimePredict",
        "Accuracy",
        "BalancedAcc",
        "Precision Macro",
        "Precision Weighted",
        "Recall Macro",
        "Recall Weighted",
        "F1-Score Macro",
        "F1-Score Weighted",
        "GMean",
        "MCC",
        "Kappa",

        "Precision_Excellent",
        "Recall_Excellent",
        "F1-Score_Excellent",
        "G-Mean_Excellent",

        "Precision_Good",
        "Recall_Good",
        "F1-Score_Good",
        "G-Mean_Good",

        "Precision_Average",
        "Recall_Average",
        "F1-Score_Average",
        "G-Mean_Average",
    ]

    ordered_cols = [c for c in ordered_cols if c in df.columns]

    df = df[ordered_cols]
    return df

# %%
# ===== RNN =====
df_rnn = run_experiment_hybrid(
    base_path=base_path,
    train_file="train_raw.parquet",
    val_file="val.parquet",
    test_prefix="test",
    version_name="Hybrid-Mask-RNN",
    rnn_type="rnn"
)
df_rnn
# Out:
# #####
# Version: Hybrid-Mask-RNN
# #####
# Loading train: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/train_raw.parquet
# Train: 1859619 | Val: 232452
# Phase 1: 39 features
# Phase 2: 39 features
# Phase 3: 39 features
# Phase 4: 39 features
# Time-series shape: (1859619, 4, 39)
# Static feature shape: (1859619, 23)
# Classes: [0 1 2]
# Epoch 1: train_loss = 0.0221 | val_loss = 0.0152
# Epoch 2: train_loss = 0.0155 | val_loss = 0.0150
# Epoch 3: train_loss = 0.0151 | val_loss = 0.0150
# Epoch 4: train_loss = 0.0150 | val_loss = 0.0146
# Epoch 5: train_loss = 0.0149 | val_loss = 0.0145
# Epoch 6: train_loss = 0.0148 | val_loss = 0.0146
# Epoch 7: train_loss = 0.0147 | val_loss = 0.0144
# Epoch 8: train_loss = 0.0147 | val_loss = 0.0143
# Epoch 9: train_loss = 0.0147 | val_loss = 0.0144
# Epoch 10: train_loss = 0.0146 | val_loss = 0.0143
# Epoch 11: train_loss = 0.0146 | val_loss = 0.0143
# Epoch 12: train_loss = 0.0146 | val_loss = 0.0143
# Epoch 13: train_loss = 0.0145 | val_loss = 0.0143
# Epoch 14: train_loss = 0.0145 | val_loss = 0.0142
# Epoch 15: train_loss = 0.0145 | val_loss = 0.0145
# Epoch 16: train_loss = 0.0145 | val_loss = 0.0144
# Epoch 17: train_loss = 0.0144 | val_loss = 0.0146
# Epoch 18: train_loss = 0.0144 | val_loss = 0.0144
# Epoch 19: train_loss = 0.0144 | val_loss = 0.0141
# Epoch 20: train_loss = 0.0144 | val_loss = 0.0142
# Epoch 21: train_loss = 0.0144 | val_loss = 0.0143
# Epoch 22: train_loss = 0.0144 | val_loss = 0.0141
# Epoch 23: train_loss = 0.0143 | val_loss = 0.0142
# Epoch 24: train_loss = 0.0144 | val_loss = 0.0141
# Epoch 25: train_loss = 0.0143 | val_loss = 0.0142
# Epoch 26: train_loss = 0.0143 | val_loss = 0.0141
# Epoch 27: train_loss = 0.0143 | val_loss = 0.0142
# Epoch 28: train_loss = 0.0143 | val_loss = 0.0141
# Epoch 29: train_loss = 0.0143 | val_loss = 0.0141
# Early stopping at epoch 29
# Training done
#
# --- Test Phase 1: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_1.parquet ---
#
# ============================== Hybrid-Mask-RNN - Phase 1 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0930232558 0.1434977578 0.1128747795       223
#         Good  0.0158598814 0.1900826446 0.0292769857       605
#      Average  0.9971982318 0.9680647598 0.9824155555    231625
#
#     accuracy                      0.9652488890    232453
#    macro avg  0.3686937897 0.4338817208 0.3748557736    232453
# weighted avg  0.9937767198 0.9652488890 0.9791006642    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.3785564281
#   Good      : 0.4292227063
#   Average   : 0.4811379708
#
# TimeBuildModel         : 1176.0953687780
# TimePredict            : 0.0455157520
# Accuracy               : 0.9652488890
# BalancedAcc            : 0.4338817208
# Precision Macro        : 0.3686937897
# Precision Weighted     : 0.9937767198
# Recall Macro           : 0.4338817208
# Recall Weighted        : 0.9652488890
# F1-Score Macro         : 0.3748557736
# F1-Score Weighted      : 0.9791006642
# GMean                  : 0.4275901071
# MCC                    : 0.0606051488
# Kappa                  : 0.0356635578
# Precision_Excellent    : 0.0930232558
# Recall_Excellent       : 0.1434977578
# F1-Score_Excellent     : 0.1128747795
# G-Mean_Excellent       : 0.3785564281
# Precision_Good         : 0.0158598814
# Recall_Good            : 0.1900826446
# F1-Score_Good          : 0.0292769857
# G-Mean_Good            : 0.4292227063
# Precision_Average      : 0.9971982318
# Recall_Average         : 0.9680647598
# F1-Score_Average       : 0.9824155555
# G-Mean_Average         : 0.4811379708
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-RNN_phase1.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-RNN_phase1.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0930232558 0.1434977578 0.1128747795       223
#         Good  0.0158598814 0.1900826446 0.0292769857       605
#      Average  0.9971982318 0.9680647598 0.9824155555    231625
#
#     accuracy                      0.9652488890    232453
#    macro avg  0.3686937897 0.4338817208 0.3748557736    232453
# weighted avg  0.9937767198 0.9652488890 0.9791006642    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.3785564281
#   Good      : 0.4292227063
#   Average   : 0.4811379708
#
# Accuracy               : 0.9652488890
# BalancedAcc            : 0.4338817208
# Precision Macro        : 0.3686937897
# Precision Weighted     : 0.9937767198
# Recall Macro           : 0.4338817208
# Recall Weighted        : 0.9652488890
# F1-Score Macro         : 0.3748557736
# F1-Score Weighted      : 0.9791006642
# GMean                  : 0.4275901071
# MCC                    : 0.0606051488
# Kappa                  : 0.0356635578
# Precision_Excellent    : 0.0930232558
# Recall_Excellent       : 0.1434977578
# F1-Score_Excellent     : 0.1128747795
# G-Mean_Excellent       : 0.3785564281
# Precision_Good         : 0.0158598814
# Recall_Good            : 0.1900826446
# F1-Score_Good          : 0.0292769857
# G-Mean_Good            : 0.4292227063
# Precision_Average      : 0.9971982318
# Recall_Average         : 0.9680647598
# F1-Score_Average       : 0.9824155555
# G-Mean_Average         : 0.4811379708
# Saved metrics to: results/metrics_Hybrid-Mask-RNN_phase1.csv
#
# --- Test Phase 2: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_2.parquet ---
#
# ============================== Hybrid-Mask-RNN - Phase 2 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.1403508772 0.1434977578 0.1419068736       223
#         Good  0.0206682373 0.3190082645 0.0388212813       605
#      Average  0.9976355732 0.9600000000 0.9784560144    231625
#
#     accuracy                      0.9575484076    232453
#    macro avg  0.3862182292 0.4741686741 0.3863947231    232453
# weighted avg  0.9942704210 0.9575484076 0.9752079192    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.3786510888
#   Good      : 0.5535569706
#   Average   : 0.5907499532
#
# TimeBuildModel         : 1176.0953687780
# TimePredict            : 0.0299606630
# Accuracy               : 0.9575484076
# BalancedAcc            : 0.4741686741
# Precision Macro        : 0.3862182292
# Precision Weighted     : 0.9942704210
# Recall Macro           : 0.4741686741
# Recall Weighted        : 0.9575484076
# F1-Score Macro         : 0.3863947231
# F1-Score Weighted      : 0.9752079192
# GMean                  : 0.4984272101
# MCC                    : 0.0848813054
# Kappa                  : 0.0452235170
# Precision_Excellent    : 0.1403508772
# Recall_Excellent       : 0.1434977578
# F1-Score_Excellent     : 0.1419068736
# G-Mean_Excellent       : 0.3786510888
# Precision_Good         : 0.0206682373
# Recall_Good            : 0.3190082645
# F1-Score_Good          : 0.0388212813
# G-Mean_Good            : 0.5535569706
# Precision_Average      : 0.9976355732
# Recall_Average         : 0.9600000000
# F1-Score_Average       : 0.9784560144
# G-Mean_Average         : 0.5907499532
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-RNN_phase2.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-RNN_phase2.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.1403508772 0.1434977578 0.1419068736       223
#         Good  0.0206682373 0.3190082645 0.0388212813       605
#      Average  0.9976355732 0.9600000000 0.9784560144    231625
#
#     accuracy                      0.9575484076    232453
#    macro avg  0.3862182292 0.4741686741 0.3863947231    232453
# weighted avg  0.9942704210 0.9575484076 0.9752079192    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.3786510888
#   Good      : 0.5535569706
#   Average   : 0.5907499532
#
# Accuracy               : 0.9575484076
# BalancedAcc            : 0.4741686741
# Precision Macro        : 0.3862182292
# Precision Weighted     : 0.9942704210
# Recall Macro           : 0.4741686741
# Recall Weighted        : 0.9575484076
# F1-Score Macro         : 0.3863947231
# F1-Score Weighted      : 0.9752079192
# GMean                  : 0.4984272101
# MCC                    : 0.0848813054
# Kappa                  : 0.0452235170
# Precision_Excellent    : 0.1403508772
# Recall_Excellent       : 0.1434977578
# F1-Score_Excellent     : 0.1419068736
# G-Mean_Excellent       : 0.3786510888
# Precision_Good         : 0.0206682373
# Recall_Good            : 0.3190082645
# F1-Score_Good          : 0.0388212813
# G-Mean_Good            : 0.5535569706
# Precision_Average      : 0.9976355732
# Recall_Average         : 0.9600000000
# F1-Score_Average       : 0.9784560144
# G-Mean_Average         : 0.5907499532
# Saved metrics to: results/metrics_Hybrid-Mask-RNN_phase2.csv
#
# --- Test Phase 3: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_3.parquet ---
#
# ============================== Hybrid-Mask-RNN - Phase 3 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.2164948454 0.1883408072 0.2014388489       223
#         Good  0.0031290504 0.3950413223 0.0062089211       605
#      Average  0.9974210601 0.6712401511 0.8024505617    231625
#
#     accuracy                      0.6700580332    232453
#    macro avg  0.4056816519 0.4182074269 0.3366994439    232453
# weighted avg  0.9940840706 0.6700580332 0.7998016313    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.4338404473
#   Good      : 0.5150771218
#   Average   : 0.5876633336
#
# TimeBuildModel         : 1176.0953687780
# TimePredict            : 0.0231449640
# Accuracy               : 0.6700580332
# BalancedAcc            : 0.4182074269
# Precision Macro        : 0.4056816519
# Precision Weighted     : 0.9940840706
# Recall Macro           : 0.4182074269
# Recall Weighted        : 0.6700580332
# F1-Score Macro         : 0.3366994439
# F1-Score Weighted      : 0.7998016313
# GMean                  : 0.5082885164
# MCC                    : 0.0180544169
# Kappa                  : 0.0030580274
# Precision_Excellent    : 0.2164948454
# Recall_Excellent       : 0.1883408072
# F1-Score_Excellent     : 0.2014388489
# G-Mean_Excellent       : 0.4338404473
# Precision_Good         : 0.0031290504
# Recall_Good            : 0.3950413223
# F1-Score_Good          : 0.0062089211
# G-Mean_Good            : 0.5150771218
# Precision_Average      : 0.9974210601
# Recall_Average         : 0.6712401511
# F1-Score_Average       : 0.8024505617
# G-Mean_Average         : 0.5876633336
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-RNN_phase3.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-RNN_phase3.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.2164948454 0.1883408072 0.2014388489       223
#         Good  0.0031290504 0.3950413223 0.0062089211       605
#      Average  0.9974210601 0.6712401511 0.8024505617    231625
#
#     accuracy                      0.6700580332    232453
#    macro avg  0.4056816519 0.4182074269 0.3366994439    232453
# weighted avg  0.9940840706 0.6700580332 0.7998016313    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.4338404473
#   Good      : 0.5150771218
#   Average   : 0.5876633336
#
# Accuracy               : 0.6700580332
# BalancedAcc            : 0.4182074269
# Precision Macro        : 0.4056816519
# Precision Weighted     : 0.9940840706
# Recall Macro           : 0.4182074269
# Recall Weighted        : 0.6700580332
# F1-Score Macro         : 0.3366994439
# F1-Score Weighted      : 0.7998016313
# GMean                  : 0.5082885164
# MCC                    : 0.0180544169
# Kappa                  : 0.0030580274
# Precision_Excellent    : 0.2164948454
# Recall_Excellent       : 0.1883408072
# F1-Score_Excellent     : 0.2014388489
# G-Mean_Excellent       : 0.4338404473
# Precision_Good         : 0.0031290504
# Recall_Good            : 0.3950413223
# F1-Score_Good          : 0.0062089211
# G-Mean_Good            : 0.5150771218
# Precision_Average      : 0.9974210601
# Recall_Average         : 0.6712401511
# F1-Score_Average       : 0.8024505617
# G-Mean_Average         : 0.5876633336
# Saved metrics to: results/metrics_Hybrid-Mask-RNN_phase3.csv
#
# --- Test Phase 4: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_4.parquet ---
#
# ============================== Hybrid-Mask-RNN - Phase 4 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.2274052478 0.3497757848 0.2756183746       223
#         Good  0.0041094703 0.5487603306 0.0081578495       605
#      Average  0.9982421475 0.6521532650 0.7889101858    231625
#
#     accuracy                      0.6515940857    232453
#    macro avg  0.4099189552 0.5168964601 0.3575621366    232453
# weighted avg  0.9949152517 0.6515940857 0.7863857217    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.5910809184
#   Good      : 0.5986041266
#   Average   : 0.6653157825
#
# TimeBuildModel         : 1176.0953687780
# TimePredict            : 0.0218909350
# Accuracy               : 0.6515940857
# BalancedAcc            : 0.5168964601
# Precision Macro        : 0.4099189552
# Precision Weighted     : 0.9949152517
# Recall Macro           : 0.5168964601
# Recall Weighted        : 0.6515940857
# F1-Score Macro         : 0.3575621366
# F1-Score Weighted      : 0.7863857217
# GMean                  : 0.6174543063
# MCC                    : 0.0357296401
# Kappa                  : 0.0057992622
# Precision_Excellent    : 0.2274052478
# Recall_Excellent       : 0.3497757848
# F1-Score_Excellent     : 0.2756183746
# G-Mean_Excellent       : 0.5910809184
# Precision_Good         : 0.0041094703
# Recall_Good            : 0.5487603306
# F1-Score_Good          : 0.0081578495
# G-Mean_Good            : 0.5986041266
# Precision_Average      : 0.9982421475
# Recall_Average         : 0.6521532650
# F1-Score_Average       : 0.7889101858
# G-Mean_Average         : 0.6653157825
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-RNN_phase4.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-RNN_phase4.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.2274052478 0.3497757848 0.2756183746       223
#         Good  0.0041094703 0.5487603306 0.0081578495       605
#      Average  0.9982421475 0.6521532650 0.7889101858    231625
#
#     accuracy                      0.6515940857    232453
#    macro avg  0.4099189552 0.5168964601 0.3575621366    232453
# weighted avg  0.9949152517 0.6515940857 0.7863857217    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.5910809184
#   Good      : 0.5986041266
#   Average   : 0.6653157825
#
# Accuracy               : 0.6515940857
# BalancedAcc            : 0.5168964601
# Precision Macro        : 0.4099189552
# Precision Weighted     : 0.9949152517
# Recall Macro           : 0.5168964601
# Recall Weighted        : 0.6515940857
# F1-Score Macro         : 0.3575621366
# F1-Score Weighted      : 0.7863857217
# GMean                  : 0.6174543063
# MCC                    : 0.0357296401
# Kappa                  : 0.0057992622
# Precision_Excellent    : 0.2274052478
# Recall_Excellent       : 0.3497757848
# F1-Score_Excellent     : 0.2756183746
# G-Mean_Excellent       : 0.5910809184
# Precision_Good         : 0.0041094703
# Recall_Good            : 0.5487603306
# F1-Score_Good          : 0.0081578495
# G-Mean_Good            : 0.5986041266
# Precision_Average      : 0.9982421475
# Recall_Average         : 0.6521532650
# F1-Score_Average       : 0.7889101858
# G-Mean_Average         : 0.6653157825
# Saved metrics to: results/metrics_Hybrid-Mask-RNN_phase4.csv
#            Version  Phase  TimeBuildModel  TimePredict  Accuracy  BalancedAcc  \
# 0  Hybrid-Mask-RNN      1     1176.095369     0.045516  0.965249     0.433882
# 1  Hybrid-Mask-RNN      2     1176.095369     0.029961  0.957548     0.474169
# 2  Hybrid-Mask-RNN      3     1176.095369     0.023145  0.670058     0.418207
# 3  Hybrid-Mask-RNN      4     1176.095369     0.021891  0.651594     0.516896
#
#    Precision Macro  Precision Weighted  Recall Macro  Recall Weighted  \
# 0         0.368694            0.993777      0.433882         0.965249
# 1         0.386218            0.994270      0.474169         0.957548
# 2         0.405682            0.994084      0.418207         0.670058
# 3         0.409919            0.994915      0.516896         0.651594
#
#    F1-Score Macro  F1-Score Weighted     GMean       MCC     Kappa  \
# 0        0.374856           0.979101  0.427590  0.060605  0.035664
# 1        0.386395           0.975208  0.498427  0.084881  0.045224
# 2        0.336699           0.799802  0.508289  0.018054  0.003058
# 3        0.357562           0.786386  0.617454  0.035730  0.005799
#
#    Precision_Excellent  Recall_Excellent  F1-Score_Excellent  \
# 0             0.093023          0.143498            0.112875
# 1             0.140351          0.143498            0.141907
# 2             0.216495          0.188341            0.201439
# 3             0.227405          0.349776            0.275618
#
#    G-Mean_Excellent  Precision_Good  Recall_Good  F1-Score_Good  G-Mean_Good  \
# 0          0.378556        0.015860     0.190083       0.029277     0.429223
# 1          0.378651        0.020668     0.319008       0.038821     0.553557
# 2          0.433840        0.003129     0.395041       0.006209     0.515077
# 3          0.591081        0.004109     0.548760       0.008158     0.598604
#
#    Precision_Average  Recall_Average  F1-Score_Average  G-Mean_Average
# 0           0.997198        0.968065          0.982416        0.481138
# 1           0.997636        0.960000          0.978456        0.590750
# 2           0.997421        0.671240          0.802451        0.587663
# 3           0.998242        0.652153          0.788910        0.665316

# %%
df_rnn.to_csv("results_rnn.csv", index=False)

# %%
# # ===== LSTM =====
# df_lstm = run_experiment_hybrid(
#     base_path=base_path,
#     train_file="train_raw.parquet",
#     val_file="val.parquet",
#     test_prefix="test",
#     version_name="Hybrid-Mask-LSTM",
#     rnn_type="lstm"
# )
# df_lstm

# %%
# df_lstm.to_csv("results_lstm.csv", index=False)

# %%
# ===== GRU =====
df_gru = run_experiment_hybrid(
    base_path=base_path,
    train_file="train_raw.parquet",
    val_file="val.parquet",
    test_prefix="test",
    version_name="Hybrid-Mask-GRU",
    rnn_type="gru"
)
df_gru
# Out:
# #####
# Version: Hybrid-Mask-GRU
# #####
# Loading train: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/train_raw.parquet
# Train: 1859619 | Val: 232452
# Phase 1: 39 features
# Phase 2: 39 features
# Phase 3: 39 features
# Phase 4: 39 features
# Time-series shape: (1859619, 4, 39)
# Static feature shape: (1859619, 23)
# Classes: [0 1 2]
# Epoch 1: train_loss = 0.0249 | val_loss = 0.0151
# Epoch 2: train_loss = 0.0152 | val_loss = 0.0147
# Epoch 3: train_loss = 0.0150 | val_loss = 0.0145
# Epoch 4: train_loss = 0.0148 | val_loss = 0.0145
# Epoch 5: train_loss = 0.0147 | val_loss = 0.0145
# Epoch 6: train_loss = 0.0146 | val_loss = 0.0143
# Epoch 7: train_loss = 0.0146 | val_loss = 0.0142
# Epoch 8: train_loss = 0.0145 | val_loss = 0.0142
# Epoch 9: train_loss = 0.0145 | val_loss = 0.0143
# Epoch 10: train_loss = 0.0144 | val_loss = 0.0141
# Epoch 11: train_loss = 0.0144 | val_loss = 0.0142
# Epoch 12: train_loss = 0.0143 | val_loss = 0.0141
# Epoch 13: train_loss = 0.0143 | val_loss = 0.0141
# Epoch 14: train_loss = 0.0142 | val_loss = 0.0141
# Epoch 15: train_loss = 0.0142 | val_loss = 0.0141
# Epoch 16: train_loss = 0.0141 | val_loss = 0.0142
# Epoch 17: train_loss = 0.0141 | val_loss = 0.0141
# Epoch 18: train_loss = 0.0141 | val_loss = 0.0141
# Epoch 19: train_loss = 0.0140 | val_loss = 0.0141
# Epoch 20: train_loss = 0.0140 | val_loss = 0.0141
# Early stopping at epoch 20
# Training done
#
# --- Test Phase 1: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_1.parquet ---
#
# ============================== Hybrid-Mask-GRU - Phase 1 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0000000000 0.0000000000 0.0000000000       223
#         Good  0.0000000000 0.0000000000 0.0000000000       605
#      Average  0.9964379896 1.0000000000 0.9982158172    231625
#
#     accuracy                      0.9964379896    232453
#    macro avg  0.3321459965 0.3333333333 0.3327386057    232453
# weighted avg  0.9928886671 0.9964379896 0.9946601621    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.0000000000
#   Good      : 0.0000000000
#   Average   : 0.0000000000
#
# TimeBuildModel         : 847.3609966620
# TimePredict            : 0.0687413040
# Accuracy               : 0.9964379896
# BalancedAcc            : 0.3333333333
# Precision Macro        : 0.3321459965
# Precision Weighted     : 0.9928886671
# Recall Macro           : 0.3333333333
# Recall Weighted        : 0.9964379896
# F1-Score Macro         : 0.3327386057
# F1-Score Weighted      : 0.9946601621
# GMean                  : 0.0000000000
# MCC                    : 0.0000000000
# Kappa                  : 0.0000000000
# Precision_Excellent    : 0.0000000000
# Recall_Excellent       : 0.0000000000
# F1-Score_Excellent     : 0.0000000000
# G-Mean_Excellent       : 0.0000000000
# Precision_Good         : 0.0000000000
# Recall_Good            : 0.0000000000
# F1-Score_Good          : 0.0000000000
# G-Mean_Good            : 0.0000000000
# Precision_Average      : 0.9964379896
# Recall_Average         : 1.0000000000
# F1-Score_Average       : 0.9982158172
# G-Mean_Average         : 0.0000000000
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-GRU_phase1.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-GRU_phase1.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0000000000 0.0000000000 0.0000000000       223
#         Good  0.0000000000 0.0000000000 0.0000000000       605
#      Average  0.9964379896 1.0000000000 0.9982158172    231625
#
#     accuracy                      0.9964379896    232453
#    macro avg  0.3321459965 0.3333333333 0.3327386057    232453
# weighted avg  0.9928886671 0.9964379896 0.9946601621    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.0000000000
#   Good      : 0.0000000000
#   Average   : 0.0000000000
#
# Accuracy               : 0.9964379896
# BalancedAcc            : 0.3333333333
# Precision Macro        : 0.3321459965
# Precision Weighted     : 0.9928886671
# Recall Macro           : 0.3333333333
# Recall Weighted        : 0.9964379896
# F1-Score Macro         : 0.3327386057
# F1-Score Weighted      : 0.9946601621
# GMean                  : 0.0000000000
# MCC                    : 0.0000000000
# Kappa                  : 0.0000000000
# Precision_Excellent    : 0.0000000000
# Recall_Excellent       : 0.0000000000
# F1-Score_Excellent     : 0.0000000000
# G-Mean_Excellent       : 0.0000000000
# Precision_Good         : 0.0000000000
# Recall_Good            : 0.0000000000
# F1-Score_Good          : 0.0000000000
# G-Mean_Good            : 0.0000000000
# Precision_Average      : 0.9964379896
# Recall_Average         : 1.0000000000
# F1-Score_Average       : 0.9982158172
# G-Mean_Average         : 0.0000000000
# Saved metrics to: results/metrics_Hybrid-Mask-GRU_phase1.csv
#
# --- Test Phase 2: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_2.parquet ---
#
# ============================== Hybrid-Mask-GRU - Phase 2 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0000000000 0.0000000000 0.0000000000       223
#         Good  0.0000000000 0.0000000000 0.0000000000       605
#      Average  0.9964379896 1.0000000000 0.9982158172    231625
#
#     accuracy                      0.9964379896    232453
#    macro avg  0.3321459965 0.3333333333 0.3327386057    232453
# weighted avg  0.9928886671 0.9964379896 0.9946601621    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.0000000000
#   Good      : 0.0000000000
#   Average   : 0.0000000000
#
# TimeBuildModel         : 847.3609966620
# TimePredict            : 0.0521926300
# Accuracy               : 0.9964379896
# BalancedAcc            : 0.3333333333
# Precision Macro        : 0.3321459965
# Precision Weighted     : 0.9928886671
# Recall Macro           : 0.3333333333
# Recall Weighted        : 0.9964379896
# F1-Score Macro         : 0.3327386057
# F1-Score Weighted      : 0.9946601621
# GMean                  : 0.0000000000
# MCC                    : 0.0000000000
# Kappa                  : 0.0000000000
# Precision_Excellent    : 0.0000000000
# Recall_Excellent       : 0.0000000000
# F1-Score_Excellent     : 0.0000000000
# G-Mean_Excellent       : 0.0000000000
# Precision_Good         : 0.0000000000
# Recall_Good            : 0.0000000000
# F1-Score_Good          : 0.0000000000
# G-Mean_Good            : 0.0000000000
# Precision_Average      : 0.9964379896
# Recall_Average         : 1.0000000000
# F1-Score_Average       : 0.9982158172
# G-Mean_Average         : 0.0000000000
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-GRU_phase2.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-GRU_phase2.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0000000000 0.0000000000 0.0000000000       223
#         Good  0.0000000000 0.0000000000 0.0000000000       605
#      Average  0.9964379896 1.0000000000 0.9982158172    231625
#
#     accuracy                      0.9964379896    232453
#    macro avg  0.3321459965 0.3333333333 0.3327386057    232453
# weighted avg  0.9928886671 0.9964379896 0.9946601621    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.0000000000
#   Good      : 0.0000000000
#   Average   : 0.0000000000
#
# Accuracy               : 0.9964379896
# BalancedAcc            : 0.3333333333
# Precision Macro        : 0.3321459965
# Precision Weighted     : 0.9928886671
# Recall Macro           : 0.3333333333
# Recall Weighted        : 0.9964379896
# F1-Score Macro         : 0.3327386057
# F1-Score Weighted      : 0.9946601621
# GMean                  : 0.0000000000
# MCC                    : 0.0000000000
# Kappa                  : 0.0000000000
# Precision_Excellent    : 0.0000000000
# Recall_Excellent       : 0.0000000000
# F1-Score_Excellent     : 0.0000000000
# G-Mean_Excellent       : 0.0000000000
# Precision_Good         : 0.0000000000
# Recall_Good            : 0.0000000000
# F1-Score_Good          : 0.0000000000
# G-Mean_Good            : 0.0000000000
# Precision_Average      : 0.9964379896
# Recall_Average         : 1.0000000000
# F1-Score_Average       : 0.9982158172
# G-Mean_Average         : 0.0000000000
# Saved metrics to: results/metrics_Hybrid-Mask-GRU_phase2.csv
#
# --- Test Phase 3: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_3.parquet ---
#
# ============================== Hybrid-Mask-GRU - Phase 3 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0000000000 0.0000000000 0.0000000000       223
#         Good  0.0000000000 0.0000000000 0.0000000000       605
#      Average  0.9964379896 1.0000000000 0.9982158172    231625
#
#     accuracy                      0.9964379896    232453
#    macro avg  0.3321459965 0.3333333333 0.3327386057    232453
# weighted avg  0.9928886671 0.9964379896 0.9946601621    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.0000000000
#   Good      : 0.0000000000
#   Average   : 0.0000000000
#
# TimeBuildModel         : 847.3609966620
# TimePredict            : 0.0358628460
# Accuracy               : 0.9964379896
# BalancedAcc            : 0.3333333333
# Precision Macro        : 0.3321459965
# Precision Weighted     : 0.9928886671
# Recall Macro           : 0.3333333333
# Recall Weighted        : 0.9964379896
# F1-Score Macro         : 0.3327386057
# F1-Score Weighted      : 0.9946601621
# GMean                  : 0.0000000000
# MCC                    : 0.0000000000
# Kappa                  : 0.0000000000
# Precision_Excellent    : 0.0000000000
# Recall_Excellent       : 0.0000000000
# F1-Score_Excellent     : 0.0000000000
# G-Mean_Excellent       : 0.0000000000
# Precision_Good         : 0.0000000000
# Recall_Good            : 0.0000000000
# F1-Score_Good          : 0.0000000000
# G-Mean_Good            : 0.0000000000
# Precision_Average      : 0.9964379896
# Recall_Average         : 1.0000000000
# F1-Score_Average       : 0.9982158172
# G-Mean_Average         : 0.0000000000
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-GRU_phase3.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-GRU_phase3.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.0000000000 0.0000000000 0.0000000000       223
#         Good  0.0000000000 0.0000000000 0.0000000000       605
#      Average  0.9964379896 1.0000000000 0.9982158172    231625
#
#     accuracy                      0.9964379896    232453
#    macro avg  0.3321459965 0.3333333333 0.3327386057    232453
# weighted avg  0.9928886671 0.9964379896 0.9946601621    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.0000000000
#   Good      : 0.0000000000
#   Average   : 0.0000000000
#
# Accuracy               : 0.9964379896
# BalancedAcc            : 0.3333333333
# Precision Macro        : 0.3321459965
# Precision Weighted     : 0.9928886671
# Recall Macro           : 0.3333333333
# Recall Weighted        : 0.9964379896
# F1-Score Macro         : 0.3327386057
# F1-Score Weighted      : 0.9946601621
# GMean                  : 0.0000000000
# MCC                    : 0.0000000000
# Kappa                  : 0.0000000000
# Precision_Excellent    : 0.0000000000
# Recall_Excellent       : 0.0000000000
# F1-Score_Excellent     : 0.0000000000
# G-Mean_Excellent       : 0.0000000000
# Precision_Good         : 0.0000000000
# Recall_Good            : 0.0000000000
# F1-Score_Good          : 0.0000000000
# G-Mean_Good            : 0.0000000000
# Precision_Average      : 0.9964379896
# Recall_Average         : 1.0000000000
# F1-Score_Average       : 0.9982158172
# G-Mean_Average         : 0.0000000000
# Saved metrics to: results/metrics_Hybrid-Mask-GRU_phase3.csv
#
# --- Test Phase 4: /kaggle/input/datasets/anhtran10/lo-dataset/Raw/Raw/test_4.parquet ---
#
# ============================== Hybrid-Mask-GRU - Phase 4 ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.9090909091 0.0448430493 0.0854700855       223
#         Good  0.1132075472 0.0198347107 0.0337552743       605
#      Average  0.9965610151 0.9996200756 0.9980882014    231625
#
#     accuracy                      0.9961540613    232453
#    macro avg  0.6729531571 0.3547659452 0.3724378537    232453
# weighted avg  0.9941780186 0.9961540613 0.9947028492    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.2117613190
#   Good      : 0.1408072051
#   Average   : 0.1871118597
#
# TimeBuildModel         : 847.3609966620
# TimePredict            : 0.0329954250
# Accuracy               : 0.9961540613
# BalancedAcc            : 0.3547659452
# Precision Macro        : 0.6729531571
# Precision Weighted     : 0.9941780186
# Recall Macro           : 0.3547659452
# Recall Weighted        : 0.9961540613
# F1-Score Macro         : 0.3724378537
# F1-Score Weighted      : 0.9947028492
# GMean                  : 0.1773607877
# MCC                    : 0.0809327880
# Kappa                  : 0.0532637704
# Precision_Excellent    : 0.9090909091
# Recall_Excellent       : 0.0448430493
# F1-Score_Excellent     : 0.0854700855
# G-Mean_Excellent       : 0.2117613190
# Precision_Good         : 0.1132075472
# Recall_Good            : 0.0198347107
# F1-Score_Good          : 0.0337552743
# G-Mean_Good            : 0.1408072051
# Precision_Average      : 0.9965610151
# Recall_Average         : 0.9996200756
# F1-Score_Average       : 0.9980882014
# G-Mean_Average         : 0.1871118597
# Saved confusion matrix to: results/confusion_matrix_Hybrid-Mask-GRU_phase4.csv
# Saved probability matrix to: results/probability_matrix_Hybrid-Mask-GRU_phase4.csv
#
# ============================== HybridModel - Phase All ==============================
#               precision    recall  f1-score   support
#
#    Excellent  0.9090909091 0.0448430493 0.0854700855       223
#         Good  0.1132075472 0.0198347107 0.0337552743       605
#      Average  0.9965610151 0.9996200756 0.9980882014    231625
#
#     accuracy                      0.9961540613    232453
#    macro avg  0.6729531571 0.3547659452 0.3724378537    232453
# weighted avg  0.9941780186 0.9961540613 0.9947028492    232453
#
# G-Mean per class (one-vs-rest):
#   Excellent : 0.2117613190
#   Good      : 0.1408072051
#   Average   : 0.1871118597
#
# Accuracy               : 0.9961540613
# BalancedAcc            : 0.3547659452
# Precision Macro        : 0.6729531571
# Precision Weighted     : 0.9941780186
# Recall Macro           : 0.3547659452
# Recall Weighted        : 0.9961540613
# F1-Score Macro         : 0.3724378537
# F1-Score Weighted      : 0.9947028492
# GMean                  : 0.1773607877
# MCC                    : 0.0809327880
# Kappa                  : 0.0532637704
# Precision_Excellent    : 0.9090909091
# Recall_Excellent       : 0.0448430493
# F1-Score_Excellent     : 0.0854700855
# G-Mean_Excellent       : 0.2117613190
# Precision_Good         : 0.1132075472
# Recall_Good            : 0.0198347107
# F1-Score_Good          : 0.0337552743
# G-Mean_Good            : 0.1408072051
# Precision_Average      : 0.9965610151
# Recall_Average         : 0.9996200756
# F1-Score_Average       : 0.9980882014
# G-Mean_Average         : 0.1871118597
# Saved metrics to: results/metrics_Hybrid-Mask-GRU_phase4.csv
#            Version  Phase  TimeBuildModel  TimePredict  Accuracy  BalancedAcc  \
# 0  Hybrid-Mask-GRU      1      847.360997     0.068741  0.996438     0.333333
# 1  Hybrid-Mask-GRU      2      847.360997     0.052193  0.996438     0.333333
# 2  Hybrid-Mask-GRU      3      847.360997     0.035863  0.996438     0.333333
# 3  Hybrid-Mask-GRU      4      847.360997     0.032995  0.996154     0.354766
#
#    Precision Macro  Precision Weighted  Recall Macro  Recall Weighted  \
# 0         0.332146            0.992889      0.333333         0.996438
# 1         0.332146            0.992889      0.333333         0.996438
# 2         0.332146            0.992889      0.333333         0.996438
# 3         0.672953            0.994178      0.354766         0.996154
#
#    F1-Score Macro  F1-Score Weighted     GMean       MCC     Kappa  \
# 0        0.332739           0.994660  0.000000  0.000000  0.000000
# 1        0.332739           0.994660  0.000000  0.000000  0.000000
# 2        0.332739           0.994660  0.000000  0.000000  0.000000
# 3        0.372438           0.994703  0.177361  0.080933  0.053264
#
#    Precision_Excellent  Recall_Excellent  F1-Score_Excellent  \
# 0             0.000000          0.000000             0.00000
# 1             0.000000          0.000000             0.00000
# 2             0.000000          0.000000             0.00000
# 3             0.909091          0.044843             0.08547
#
#    G-Mean_Excellent  Precision_Good  Recall_Good  F1-Score_Good  G-Mean_Good  \
# 0          0.000000        0.000000     0.000000       0.000000     0.000000
# 1          0.000000        0.000000     0.000000       0.000000     0.000000
# 2          0.000000        0.000000     0.000000       0.000000     0.000000
# 3          0.211761        0.113208     0.019835       0.033755     0.140807
#
#    Precision_Average  Recall_Average  F1-Score_Average  G-Mean_Average
# 0           0.996438         1.00000          0.998216        0.000000
# 1           0.996438         1.00000          0.998216        0.000000
# 2           0.996438         1.00000          0.998216        0.000000
# 3           0.996561         0.99962          0.998088        0.187112

# %%
df_gru.to_csv("results_gru.csv", index=False)

# %%
# # ===== BiLSTM =====
# df_bilstm = run_experiment_hybrid(
#     base_path=base_path,
#     train_file="train_raw.parquet",
#     val_file="val.parquet",
#     test_prefix="test",
#     version_name="Hybrid-Mask-BiLSTM",
#     rnn_type="bilstm"
# )
# df_bilstm

# %%
# df_bilstm.to_csv("results_bilstm.csv", index=False)
